# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/shaw8/datamining/hw2/adult.csv")
dt=pd.read_csv("C:/Users/shaw8/datamining/hw2/adult_test.csv")
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        salary
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
dt
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 0       25        Private  226802           11th              7
# 1       38        Private   89814        HS-grad              9
# 2       28      Local-gov  336951     Assoc-acdm             12
# 3       44        Private  160323   Some-college             10
# 4       18              ?  103497   Some-college             10
# ...    ...            ...     ...            ...            ...
# 16276   39        Private  215419      Bachelors             13
# 16277   64              ?  321403        HS-grad              9
# 16278   38        Private  374983      Bachelors             13
# 16279   44        Private   83891      Bachelors             13
# 16280   35   Self-emp-inc  182148      Bachelors             13
#
#             marital-status          occupation     relationship  \
# 0            Never-married   Machine-op-inspct        Own-child
# 1       Married-civ-spouse     Farming-fishing          Husband
# 2       Married-civ-spouse     Protective-serv          Husband
# 3       Married-civ-spouse   Machine-op-inspct          Husband
# 4            Never-married                   ?        Own-child
# ...                    ...                 ...              ...
# 16276             Divorced      Prof-specialty    Not-in-family
# 16277              Widowed                   ?   Other-relative
# 16278   Married-civ-spouse      Prof-specialty          Husband
# 16279             Divorced        Adm-clerical        Own-child
# 16280   Married-civ-spouse     Exec-managerial          Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    Black     Male             0             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male          7688             0
# 4                    White   Female             0             0
# ...                    ...      ...           ...           ...
# 16276                White   Female             0             0
# 16277                Black     Male             0             0
# 16278                White     Male             0             0
# 16279   Asian-Pac-Islander     Male          5455             0
# 16280                White     Male             0             0
#
#        hours-per-week  native-country   salary
# 0                  40   United-States   <=50K.
# 1                  50   United-States   <=50K.
# 2                  40   United-States    >50K.
# 3                  40   United-States    >50K.
# 4                  30   United-States   <=50K.
# ...               ...             ...      ...
# 16276              36   United-States   <=50K.
# 16277              40   United-States   <=50K.
# 16278              50   United-States   <=50K.
# 16279              40   United-States   <=50K.
# 16280              60   United-States    >50K.
#
# [16281 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
dt.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
dt.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  16281.000000  1.628100e+04   16281.000000  16281.000000  16281.000000
# mean      38.767459  1.894357e+05      10.072907   1081.905104     87.899269
# std       13.849187  1.057149e+05       2.567545   7583.935968    403.105286
# min       17.000000  1.349200e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.167360e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.778310e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.383840e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   3770.000000
#
#        hours-per-week
# count    16281.000000
# mean        40.392236
# std         12.479332
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
dt.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
df.apply(lambda x:np.sum(x==' ?'))
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# salary               0
# dtype: int64

# %%
dt.apply(lambda x:np.sum(x==' ?'))
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# salary              0
# dtype: int64

# %%
fliter1 = (df["native-country"] != ' ?')
fliter2 = (df["occupation"] != ' ?')
fliter3 = (df["workclass"] != ' ?')
df_1 = df[fliter1 & fliter2 & fliter3]
print(df_1['native-country'].value_counts())
print(df_1['occupation'].value_counts())
print(df_1['workclass'].value_counts())
# Out:
#  United-States                 27504
#  Mexico                          610
#  Philippines                     188
#  Germany                         128
#  Puerto-Rico                     109
#  Canada                          107
#  India                           100
#  El-Salvador                     100
#  Cuba                             92
#  England                          86
#  Jamaica                          80
#  South                            71
#  China                            68
#  Italy                            68
#  Dominican-Republic               67
#  Vietnam                          64
#  Guatemala                        63
#  Japan                            59
#  Poland                           56
#  Columbia                         56
#  Iran                             42
#  Taiwan                           42
#  Haiti                            42
#  Portugal                         34
#  Nicaragua                        33
#  Peru                             30
#  Greece                           29
#  France                           27
#  Ecuador                          27
#  Ireland                          24
#  Hong                             19
#  Cambodia                         18
#  Trinadad&Tobago                  18
#  Thailand                         17
#  Laos                             17
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         12
#  Scotland                         11
#  Holand-Netherlands                1
# Name: native-country, dtype: int64
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1966
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: occupation, dtype: int64
#  Private             22286
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: workclass, dtype: int64

# %%
fliter1 = (dt["native-country"] != ' ?')
fliter2 = (dt["occupation"] != ' ?')
fliter3 = (dt["workclass"] != ' ?')
dt_1 = dt[fliter1 & fliter2 & fliter3]
print(dt_1['native-country'].value_counts())
print(dt_1['occupation'].value_counts())
print(dt_1['workclass'].value_counts())
# Out:
#  United-States                 13788
#  Mexico                          293
#  Philippines                      95
#  Puerto-Rico                      66
#  Germany                          65
#  Canada                           56
#  El-Salvador                      47
#  India                            47
#  China                            45
#  Cuba                             41
#  England                          33
#  Italy                            32
#  South                            30
#  Dominican-Republic               30
#  Japan                            30
#  Portugal                         28
#  Haiti                            27
#  Columbia                         26
#  Poland                           25
#  Guatemala                        23
#  Jamaica                          23
#  Greece                           20
#  Vietnam                          19
#  Ecuador                          16
#  Nicaragua                        15
#  Peru                             15
#  Iran                             14
#  Taiwan                           13
#  Thailand                         12
#  Ireland                          12
#  Hong                              9
#  Scotland                          9
#  France                            9
#  Outlying-US(Guam-USVI-etc)        8
#  Trinadad&Tobago                   8
#  Cambodia                          8
#  Yugoslavia                        7
#  Honduras                          7
#  Hungary                           5
#  Laos                              4
# Name: native-country, dtype: int64
#  Exec-managerial      1992
#  Craft-repair         1990
#  Prof-specialty       1970
#  Sales                1824
#  Adm-clerical         1819
#  Other-service        1596
#  Machine-op-inspct    1004
#  Transport-moving      744
#  Handlers-cleaners     696
#  Tech-support          508
#  Farming-fishing       491
#  Protective-serv       332
#  Priv-house-serv        89
#  Armed-Forces            5
# Name: occupation, dtype: int64
#  Private             11021
#  Self-emp-not-inc     1297
#  Local-gov            1033
#  State-gov             667
#  Self-emp-inc          572
#  Federal-gov           463
#  Without-pay             7
# Name: workclass, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df_2= df_1
df_2['workclass'] = labelencoder.fit_transform(df_1['workclass'])
df_2['education']=labelencoder.fit_transform(df_1['education'])
df_2['occupation'] = labelencoder.fit_transform(df_1['occupation'])
df_2['marital-status'] = labelencoder.fit_transform(df_1['marital-status'])
df_2['relationship'] = labelencoder.fit_transform(df_1['relationship'])
df_2['race'] = labelencoder.fit_transform(df_1['race'])
df_2['sex'] = labelencoder.fit_transform(df_1['sex'])
df_2['native-country'] = labelencoder.fit_transform(df_1['native-country'])
df_2['salary'] = labelencoder.fit_transform(df_1['salary'])
df_2
# Out:
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/4068754672.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['workclass'] = labelencoder.fit_transform(df_1['workclass'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/4068754672.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['education']=labelencoder.fit_transform(df_1['education'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/4068754672.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['occupation'] = labelencoder.fit_transform(df_1['occupation'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/4068754672.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['marital-status'] = labelencoder.fit_transform(df_1['marital-status'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/4068754672.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['relationship'] = labelencoder.fit_transform(df_1['relationship'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/4068754672.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['race'] = labelencoder.fit_transform(df_1['race'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/4068754672.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['sex'] = labelencoder.fit_transform(df_1['sex'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/4068754672.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['native-country'] = labelencoder.fit_transform(df_1['native-country'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/4068754672.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['salary'] = labelencoder.fit_transform(df_1['salary'])
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          5   77516          9             13               4
# 1       50          4   83311          9             13               2
# 2       38          2  215646         11              9               0
# 3       53          2  234721          1              7               2
# 4       28          2  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          2  257302          7             12               2
# 32557   40          2  154374         11              9               2
# 32558   58          2  151910         11              9               6
# 32559   22          2  201490         11              9               4
# 32560   52          3  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0               0             1     4    1          2174             0
# 1               3             0     4    1             0             0
# 2               5             1     4    1             0             0
# 3               5             0     2    1             0             0
# 4               9             5     2    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32556          12             5     4    0             0             0
# 32557           6             0     4    1             0             0
# 32558           0             4     4    0             0             0
# 32559           0             3     4    1             0             0
# 32560           3             5     4    0         15024             0
#
#        hours-per-week  native-country  salary
# 0                  40              38       0
# 1                  13              38       0
# 2                  40              38       0
# 3                  40              38       0
# 4                  40               4       0
# ...               ...             ...     ...
# 32556              38              38       0
# 32557              40              38       1
# 32558              40              38       0
# 32559              20              38       0
# 32560              40              38       1
#
# [30162 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
dt_2= dt_1
dt_2['workclass'] = labelencoder.fit_transform(dt_1['workclass'])
dt_2['education']=labelencoder.fit_transform(dt_1['education'])
dt_2['occupation'] = labelencoder.fit_transform(dt_1['occupation'])
dt_2['marital-status'] = labelencoder.fit_transform(dt_1['marital-status'])
dt_2['relationship'] = labelencoder.fit_transform(dt_1['relationship'])
dt_2['race'] = labelencoder.fit_transform(dt_1['race'])
dt_2['sex'] = labelencoder.fit_transform(dt_1['sex'])
dt_2['native-country'] = labelencoder.fit_transform(dt_1['native-country'])
dt_2['salary'] = labelencoder.fit_transform(dt_1['salary'])
dt_2
# Out:
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/2358533984.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_2['workclass'] = labelencoder.fit_transform(dt_1['workclass'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/2358533984.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_2['education']=labelencoder.fit_transform(dt_1['education'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/2358533984.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_2['occupation'] = labelencoder.fit_transform(dt_1['occupation'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/2358533984.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_2['marital-status'] = labelencoder.fit_transform(dt_1['marital-status'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/2358533984.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_2['relationship'] = labelencoder.fit_transform(dt_1['relationship'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/2358533984.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_2['race'] = labelencoder.fit_transform(dt_1['race'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/2358533984.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_2['sex'] = labelencoder.fit_transform(dt_1['sex'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/2358533984.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_2['native-country'] = labelencoder.fit_transform(dt_1['native-country'])
# C:\Users\shaw8\AppData\Local\Temp/ipykernel_17076/2358533984.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt_2['salary'] = labelencoder.fit_transform(dt_1['salary'])
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       25          2  226802          1              7               4
# 1       38          2   89814         11              9               2
# 2       28          1  336951          7             12               2
# 3       44          2  160323         15             10               2
# 5       34          2  198693          0              6               4
# ...    ...        ...     ...        ...            ...             ...
# 16275   33          2  245211          9             13               4
# 16276   39          2  215419          9             13               0
# 16278   38          2  374983          9             13               2
# 16279   44          2   83891          9             13               0
# 16280   35          3  182148          9             13               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0               6             3     2    1             0             0
# 1               4             0     4    1             0             0
# 2              10             0     4    1             0             0
# 3               6             0     2    1          7688             0
# 5               7             1     4    1             0             0
# ...           ...           ...   ...  ...           ...           ...
# 16275           9             3     4    1             0             0
# 16276           9             1     4    0             0             0
# 16278           9             0     4    1             0             0
# 16279           0             3     1    1          5455             0
# 16280           3             0     4    1             0             0
#
#        hours-per-week  native-country  salary
# 0                  40              37       0
# 1                  50              37       0
# 2                  40              37       1
# 3                  40              37       1
# 5                  30              37       0
# ...               ...             ...     ...
# 16275              40              37       0
# 16276              36              37       0
# 16278              50              37       0
# 16279              40              37       0
# 16280              60              37       1
#
# [15060 rows x 15 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df_3=scaler.fit_transform(df_2)
df_4=pd.DataFrame(df_3,columns=df_2.columns)

# %%
x_train=df_4.drop('hours-per-week',axis=1)
y_train=df_4['hours-per-week']

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100, n_jobs=-1,
oob_score=True, bootstrap=True,
random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, oob_score=True, random_state=42)

# %%
y_train.pred=rf.predict(x_train)

# %%
print('R^2 Training Score: {:.2f} \nOOB Score: {:.2f} \nR^2 Validation Score: {:.2f}'.format(rf.score(x_train, y_train),rf.oob_score_,rf.score(x_train, y_train)))
# Out:
# R^2 Training Score: 0.89
# OOB Score: 0.18
# R^2 Validation Score: 0.89

# %%
from sklearn.metrics import mean_absolute_error
print('MAE',mean_absolute_error(y_train,y_train.pred))
# Out:
# MAE 0.028207242573506576

# %%
from sklearn.metrics import mean_squared_error
print('RMSE',np.sqrt(mean_squared_error(y_train,y_train.pred)))
# Out:
# RMSE 0.04097206168693808

# %%
from sklearn.metrics import mean_absolute_percentage_error
print('MAPE',mean_absolute_percentage_error(y_train,y_train.pred))
# Out:
# MAPE 141969897681.32828
